# %%
import numpy as np
import urllib3
import json
from sys import argv
import pandas as pd
import numpy as np

# %% [markdown]
# __DESCRIPTION:__ This notebook is used to gather county, city and fips codes from the U.S. Small Business Administration API. <br>
#
# __FINAL OUTPUT:__ <br>
#  - US_SBA_api.csv -- Compiled API data from US SBA. Used in the SPLC Cleaning Notebook.

# %%
# List of states
state = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND',  'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

# URL sections
suff = ".json"
linkbase = "http://api.sba.gov/geodata/all_data_for_city_of/CITY_NAME/STATE_ABBREVIATION.FORMAT"
http = urllib3.PoolManager()

# Loop through list of states to get associated data for each state
for item in state:
    
    # Start the final dataframe with the first item in the list
    if item == 'AL':
        addr = linkbase + item + suff
        datum = http.request('GET', addr)
        clean_datum = json.loads(datum.data.decode('utf-8'))
        mergedf1 = pd.DataFrame(clean_datum)
    
    # Now go through the rest of the list and concatenate results to the first dataframe
    else:
        addr = linkbase + item + suff
        datum = http.request('GET', addr)
        clean_datum = json.loads(datum.data.decode('utf-8'))
        output = pd.DataFrame(clean_datum)
        mergedf1 = pd.concat([mergedf1,output])

# Flag to signal completion
print("done")

# Save file
mergedf.to_csv("US_SBA_api.csv", encoding = "utf-8")
# Out:
# done
#   county_name description       feat_class feature_id fips_class  \
# 0      Mobile        None  Populated Place        256         C1
# 1      Morgan        None  Populated Place        260         C1
# 2     Marengo        None  Populated Place        261         C1
# 3     Baldwin        None  Populated Place        518         C1
# 4     Houston        None  Populated Place        265         C1
#
#   fips_county_cd full_county_name link_title            name primary_latitude  \
# 0             97    Mobile County       None  Dauphin Island            30.25
# 1            103    Morgan County       None         Decatur             34.6
# 2             91   Marengo County       None       Demopolis            32.51
# 3              3   Baldwin County       None     Robertsdale            30.55
# 4             69   Houston County       None          Dothan            31.22
#
#   primary_longitude state_abbreviation state_name  \
# ...
