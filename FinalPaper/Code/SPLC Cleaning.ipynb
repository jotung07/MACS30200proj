# %%
# %matplotlib inline

# Import Packages
import pandas as pd
import numpy  as np
from matplotlib import pyplot as plt

# %% [markdown]
# __DESCRIPTION:__ This notebook is used to prepare the Southern Poverty Law Center data for analysis. Cleaning steps proceed as follows. <br>
#
# 1. Flag records that indicate militia activity (records marked with an asterisk). <br>
# 2. Assign each record to the relevant county or counties (some cities are located in more than one county). This is accomplished in two passes. Each pass utilizes a different set database to perform the county assignment. The results from the two passes are merged and flagged for discrepancies. <br>
# 3. Manual validation of records. Data is exported to Excel. County location(s) and mismatched records are validated through Google search and corrected in the table. Modified table is saved as ...DONE.xlsx and reimported into pandas to verify completeness of county assignments. <br>
# 4. Assign FIPS codes. <br>
# 5. Drop records that are listed as occurring STATEWIDE, that were listed as having no location (UNKNOWN) or that indicate a large regions of a state. <br>
# 6. Save the final data as .csv file. <br>
#
# __INPUTS USED:__ <br>
#  - SPLC_Fin.xlsx -- This is the consolidated and reformatted Southern Poverty Law Center data for years 2007-2015, copied from the SPLC Intelligence Report articles. See files Antigov.xlsx and Antigov_Check.xlsx for the files that created this dataset. <br>
#
#  - zip_codes_states.csv -- Used in FIRST PASS of county assignment. Dataset from gaslampmedia.com matching zip code to city and county. (Note, during the cleaning process, errors in the county/city match were observed when an outer join was used to merge this dataset to the SPLC dataset. Since the second pass and manual checks would capture any unmatched records, a dictionary was used to assign county records to the SPLC data instead.) <br>
#
#  - US_SBA_api.csv -- Dataset obtained from the U.S. Small Business Administration API that contains county, city and fips code. This data appears to be of good quality. I split the SPLC data into those whose locations are identified at the county level and those whose locations are at the city level, and merge the city level data with the US_SBA_api data. <br>
#
#  - Checkmap.xlsx -- This is a manual database I created that matched city to county during an earlier pass at cleaning the data. I used this to assign county or counties to records flagged for mismatch or no match. <br>
#
#  - national_county.txt -- This is a database from the U.S. Census Bureau matching county to state and county FIPS codes. <br>
#
# __FINAL OUTPUT:__ <br>
#  - SPLC_CLEAN.xlsx -- Final SPLC dataset. Used in SPLC to ACS Jupyter Notebook.

# %%
# PASS ONE

# Import SPLC data
asplc = pd.read_excel("SPLC_Fin.xlsx")

# Add State Code Abbreviations to the SPLC Dataset
state1 = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']
state2 = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND',  'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']
state_dict = dict(zip(state1, state2))
asplc["ST"] = asplc["State"].map(state_dict)

# Flag Militia locations
asplc["Militia"] = np.where(asplc['Name'].str.contains(r'\*'), "Yes", "No")
asplc["Militia"] = np.where(asplc['Raw'].str.contains(r'\*'), "Yes", asplc["Militia"])
asplc["Militia2"] = np.where(asplc['Name'].str.contains("Militia"), "Yes", asplc["Militia"])

# Remove asterisks from the Raw field where the location is stored
asplc['Raw'] = asplc['Raw'].map(lambda x: x.rstrip(r'\*'))

# Code city_state
asplc['state_city'] = asplc['ST'] + "_" + asplc['Raw']

# Import dataset with City to County conversion
geobase = pd.read_csv("zip_codes_states.csv")
geobase.head()

# Assign state_city code
geobase["County_P1"] = geobase["county"] + " County"
geobase['state_city'] = geobase["state"] + "_" + geobase['city']

# Create dictionary of County to state_city
tryit_dict = dict(zip(geobase.state_city, geobase.County_P1))

# Map county =to city in SPLC dataset using tryit_dict, with state_city as key
asplc['County_P1'] = np.where(~asplc['Raw'].str.contains("County"), asplc['state_city'].map(tryit_dict), asplc['Raw'])

asplc.head()
# Out:
#      State                              Name  Year       Raw  ST Militia  \
# 0  Alabama                Constitution Party  2007   Cullman  AL      No
# 1   Alaska                Constitution Party  2007     Kenai  AK      No
# 2  Arizona  American Patriot Friends Network  2007  Glendale  AZ      No
# 3  Arizona          Arizona Citizens Militia  2007   Douglas  AZ      No
# 4  Arizona                   Arizona Militia  2007  Glendale  AZ      No
#
#   Militia2   state_city               County_P1
# 0       No   AL_Cullman          Cullman County
# 1       No     AK_Kenai  Kenai Peninsula County
# 2       No  AZ_Glendale         Maricopa County
# 3      Yes   AZ_Douglas          Cochise County
# 4      Yes  AZ_Glendale         Maricopa County

# %%
#PASS TWO:

# GET THE US SBA API DATA READY
# Import API dataset with city, county, and FIPS id
geodf = pd.read_csv("US_SBA_api.csv", index_col = None, usecols =['county_name', 'fips_county_cd', 'full_county_name', 'name', \
                                                              'state_abbreviation', 'state_name'])
# Assign state_city code
geodf['state_city'] = geodf['state_abbreviation'] + "_" + geodf['name']
# Assign state_county code
geodf['state_county'] = geodf['state_abbreviation'] + "_" + geodf['full_county_name']

# Convert FIPS county code into three-digit string
geodf[['fips_county_cd']] = geodf[['fips_county_cd']].astype('str')
geodf['fips_id'] = geodf['fips_county_cd'].str.zfill(3)

# Create dictionary of state_county and fips id
geo_dict = dict(zip(geodf.state_county, geodf.fips_id))



# Import SPLC data
bsplc = pd.read_excel("SPLC_Fin.xlsx")

# Flag Militia locations
bsplc["Militia"] = np.where(bsplc['Name'].str.contains(r'\*'), "Yes", "No")
bsplc["Militia"] = np.where(bsplc['Raw'].str.contains(r'\*'), "Yes", bsplc["Militia"])
bsplc["Militia2"] = np.where(bsplc['Name'].str.contains("Militia"), "Yes", bsplc["Militia"])

# Add State Code Abbreviations to the SPLC Dataset
state1 = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']
state2 = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND',  'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']
state_dict = dict(zip(state1, state2))
bsplc["ST"] = bsplc["State"].map(state_dict)

# Remove Asterisks from Raw field
bsplc['Raw'] = bsplc['Raw'].map(lambda x: x.rstrip(r'\*'))
bsplc['state_city'] = bsplc['ST'] + "_" + bsplc['Raw']

# Separate out records that are located in counties versus cities
bcounty = bsplc[bsplc['Raw'].str.contains('County')].copy()
bcity = bsplc[~bsplc['Raw'].str.contains('County')].copy()

# Merge city dataset with US SBA dataset
bcity_fin = pd.merge(bcity, geodf, how = 'inner', left_on = 'state_city', right_on = 'state_city', indicator = 'P2_merge')

# Join the county and city datasets
finbdf = pd.concat([bcounty, bcity_fin], join = 'outer')

# Assign county 
finbdf['County_P2'] = np.where(finbdf.Raw.str.contains('County'), finbdf.Raw, finbdf.full_county_name)

# Get rid of unnecessary columns and make copy of dataframe
finbsplc = finbdf[['State', 'Name', 'Raw', 'Year', 'Militia', 'Militia2', 'County_P2', 'fips_id', 'ST']].copy()
finbsplc.head()
# Out:
#       State                                    Name              Raw  Year  \
# 26  Georgia                         Georgia Militia   Chatham County  2007
# 27  Georgia                         Georgia Militia      Cobb County  2007
# 28  Georgia                         Georgia Militia  Gwinnett County  2007
# 29  Georgia                         Georgia Militia  Stephens County  2007
# 86     Ohio  Constitutional Militia of Clark County     Clark County  2007
#
#    Militia Militia2        County_P2 fips_id  ST
# 26      No      Yes   Chatham County     NaN  GA
# 27      No      Yes      Cobb County     NaN  GA
# 28      No      Yes  Gwinnett County     NaN  GA
# 29      No      Yes  Stephens County     NaN  GA
# 86      No      Yes     Clark County     NaN  OH

# %%
# JOIN PASSES ONE AND TWO

# Create unique label for each record from Name, Year, State and City
asplc['id'] = asplc.Year.map(str) + "_" + asplc.Name + "_" + asplc.ST + "_" + asplc.Raw
finbsplc['id'] = finbsplc.Year.map(str) + "_" + finbsplc.Name + "_" + finbsplc.ST + "_" + finbsplc.Raw

# Merge the Pass 1 and 2 datasets on id
test = pd.merge(asplc, finbsplc.loc[:,('County_P2', 'fips_id', 'id')], how = 'outer', on = 'id', indicator = 'P3_merge')
test.head()
# Out:
#      State                              Name  Year       Raw  ST Militia  \
# 0  Alabama                Constitution Party  2007   Cullman  AL      No
# 1   Alaska                Constitution Party  2007     Kenai  AK      No
# 2  Arizona  American Patriot Friends Network  2007  Glendale  AZ      No
# 3  Arizona          Arizona Citizens Militia  2007   Douglas  AZ      No
# 4  Arizona                   Arizona Militia  2007  Glendale  AZ      No
#
#   Militia2   state_city               County_P1  \
# 0       No   AL_Cullman          Cullman County
# 1       No     AK_Kenai  Kenai Peninsula County
# 2       No  AZ_Glendale         Maricopa County
# 3      Yes   AZ_Douglas          Cochise County
# 4      Yes  AZ_Glendale         Maricopa County
#
#                                                   id                County_P2  \
# 0                 2007_Constitution Party_AL_Cullman           Cullman County
# 1                   2007_Constitution Party_AK_Kenai  Kenai Peninsula Borough
# 2  2007_American Patriot Friends Network_AZ_Glendale          Maricopa County
# 3           2007_Arizona Citizens Militia_AZ_Douglas                      NaN
# 4                   2007_Arizona Militia_AZ_Glendale          Maricopa County
#
#   fips_id   P3_merge
# 0     043       both
# 1     122       both
# 2     013       both
# 3     NaN  left_only
# 4     013       both

# %%
# CHECK FOR DISCREPANCIES IN THE MATCHES AND ASSIGN THE COUNTY

# Create a column to flag mismatches between the two passes
test['flag_p12'] = np.where(test.County_P1 == test.County_P2, 'Match', \
                        np.where((pd.isnull(test.County_P1)) & (pd.isnull(test.County_P2)), "No Match", "Mismatch"))
#test1[(test1._merge != 'both') & (test1.flag == 'No Match')]
#test.groupby('flag_p12').count()

# Assign the County based on the flag
test['County_P3'] = np.where(test.flag_p12 == 'Match', test.County_P2, \
                               np.where((~pd.isnull(test.County_P2)) & (pd.isnull(test.County_P1)), test.County_P2, \
                                                np.where((~pd.isnull(test.County_P1)) & (pd.isnull(test.County_P2)), test.County_P1, \
                                                        np.where((test.flag_p12 == 'Mismatch'), "Error", "No Match"))))

# Export to excel for manual validation
test.to_excel('SPLC_CheckIt.xlsx', encoding = 'utf-8')

# %%
# IMPORT CHECK ONE RESULTS
df= pd.read_excel('SPLC_CheckIt_Done.xlsx')

# Drop records flagged for drop (due to no match found or erroneous record)
check1 = df[df['Check'] != 'dropit'].copy()

# Determine county assignment based on flags
check1['County_P4'] = np.where(check1['Check'] == 'Keep2', check1.County_P2, \
                               np.where(check1['Check'] == 'st_unk', 'None', check1.County_P3))
# check1[check1['Check'] == 'Keep2']

# Import checkmap table
checkmap = pd.read_excel('Check_map.xlsx', usecols = ['state_city', 'Final', 'Fix2', 'Note'])

# Flag only those records that are useful
checkmap1 = checkmap[(checkmap['Final'] == 1) | (checkmap['Final'] == 3)]
# Drop duplicate records that will cause unnecessary overmatch
checkmap1 = checkmap1.drop_duplicates()

# Merge the checkmap records to the check1 dataset to resolve whatever discrepancies can be resolved
testcheck = pd.merge(check1, checkmap1, how = 'left', on = 'state_city', indicator = 'testcheck_merge')
# Assign county based on the check results
testcheck['County_P5'] = np.where((testcheck.County_P4 == 'No Match') & (~pd.isnull(testcheck.Fix2)), testcheck.Fix2, \
                                 np.where(((testcheck.County_P4 != 'No Match') | (testcheck.County_P4 != 'None')), testcheck.County_P4, \
                                          np.where((testcheck.County_P4 == 'None'), "None", "Error")))

# Export to Excel for Manual Check #2
testcheck.to_excel('SPLC_CheckIt_Twice.xlsx')

# %%
# Import the results from the Manual Check #2
check2 = pd.read_excel('SPLC_CheckIt_Twice_Done.xlsx')

# Assign county based on the results from Check #2
check2['County_P6'] = np.where((check2.County_P5 == 'No Match') & (check2.Check == 'Keep2'), check2.County_P2, check2.County_P5)
 
#check2[(check2['County_P6'] != 'None') & (check2['County_P6'] != 'No Match')]
# Out:
#       Column2  Column1                 State  \
# 0           0       16              Colorado
# 1           1        8            California
# 2           2      135             Wisconsin
# 3           3      136             Wisconsin
# 4           4      137             Wisconsin
# 5           5        2               Arizona
# 6           6        3               Arizona
# 7           7        4               Arizona
# 9        6688     6233             Minnesota
# 10         10      121                 Texas
# 11         11      122                 Texas
# 12         12        9            California
# 13         13       68                Nevada
# 14         14      123                 Texas
# 15         15       17              Colorado
# 16         16       20           Connecticut
# 17         17        1                Alaska
# 18         18        0               Alabama
# 19         19        6              Arkansas
# 20         20        5               Arizona
# 21         21       18              Colorado
# 22         22       21           Connecticut
# 23         23       23  District of Columbia
# 24         24       22              Delaware
# 25         25       24               Florida
# 26         26       25               Georgia
# 27         27       31                Hawaii
# 28         28       43                  Iowa
# 29         29       32                 Idaho
# 30         30       34              Illinois
# ...       ...      ...                   ...
# 8642     8642     8471            Washington
# 8643     8643     8472            Washington
# 8644     8644     7926            California
# 8645     8645     8071              Kentucky
# 8647     8647     8087                 Maine
# 8648     8648     7927            California
# 8649     8649     7928            California
# 8650     8650     7929            California
# 8652     8652     7940              Colorado
# 8653     8653     7949           Connecticut
# 8654     8654     7982               Florida
# 8655     8655     7983               Florida
# 8656     8656     7984               Florida
# 8657     8657     8031              Illinois
# 8658     8658     8088                 Maine
# 8659     8659     8117              Michigan
# 8660     8660     8190         New Hampshire
# 8661     8661     8183                Nevada
# 8662     8662     8328          Rhode Island
# 8663     8663     8473            Washington
# 8664     8664     8238              New York
# 8665     8665     8118              Michigan
# 8666     8666     8307                Oregon
# 8667     8667     8323          Pennsylvania
# 8668     8668     8191         New Hampshire
# 8669     8669     7985               Florida
# 8670     8670     7956  District of Columbia
# 8671     8671     7957  District of Columbia
# 8673     1238     1428          North Dakota
# 8688     1238     1428          North Dakota
#
#                                             Name  Year                 Raw  \
# 0                       American Freedom Network  2007           Johnstown
# 1                     American Independent Party  2007         Lemon Grove
# 2                 American Opinion Book Services  2007            Appleton
# 3                 American Opinion Book Services  2007            Appleton
# 4                 American Opinion Book Services  2007            Appleton
# 5               American Patriot Friends Network  2007            Glendale
# 6                       Arizona Citizens Militia  2007             Douglas
# 7                                Arizona Militia  2007            Glendale
# 9                                  We Are Change  2014         Cedar Falls
# 10                                 Border Rescue  2007          Richardson
# 11                           Buffalo Creek Press  2007            Cleburne
# 12                            California Militia  2007                Brea
# 13                             Center for Action  2007        Sandy Valley
# 14        Church of God Evangelistic Association  2007          Waxahachie
# 15                  Colorado State Defense Force  2007          Canon City
# 16              Connecticut Survivalist Alliance  2007         Middlefield
# 17                            Constitution Party  2007               Kenai
# 18                            Constitution Party  2007             Cullman
# 19                            Constitution Party  2007        Fayetteville
# 20                            Constitution Party  2007       Golden Valley
# 21                            Constitution Party  2007              Arvada
# 22                            Constitution Party  2007             Wolcott
# 23                            Constitution Party  2007          Washington
# 24                            Constitution Party  2007          Middletown
# 25                            Constitution Party  2007             Jupiter
# 26                            Constitution Party  2007           Woodstock
# 27                            Constitution Party  2007            Honolulu
# 28                            Constitution Party  2007           Oskaloosa
# 29                            Constitution Party  2007               Parma
# 30                            Constitution Party  2007     Rolling Meadows
# ...                                          ...   ...                 ...
# 8642              Washington Light Foot Militia*  2016      Spokane County
# 8643              Washington Light Foot Militia*  2016       Yakima County
# 8644           Washitaw Empire de Dugdahmoundyah  2016           San Pedro
# 8645                         Watchmen of America  2016           Lexington
# 8647                          Watchmen of Maine*  2016             Sanford
# 8648                               We Are Change  2016              Fresno
# 8649                               We Are Change  2016         Los Angeles
# 8650                               We Are Change  2016         Los Angeles
# 8652                               We Are Change  2016          Walsenburg
# 8653                               We Are Change  2016           Waterbury
# 8654                               We Are Change  2016             Orlando
# 8655                               We Are Change  2016          Palm Beach
# 8656                               We Are Change  2016               Tampa
# 8657                               We Are Change  2016             Chicago
# 8658                               We Are Change  2016              Bangor
# 8659                               We Are Change  2016        Grand Rapids
# 8660                               We Are Change  2016          Manchester
# 8661                               We Are Change  2016           Las Vegas
# 8662                               We Are Change  2016          Providence
# 8663                               We Are Change  2016             Spokane
# 8664                               We the People  2016          Queensbury
# 8665            West Michigan Volunteer Militia*  2016     Muskegon County
# 8666           West Valley Constitutional Guard*  2016      Yamhill County
# 8667                    Western PA Liberty Forum  2016          Grove City
# 8668                        What Really Happened  2016             Concord
# 8669                       Wild Bill for America  2016       South Daytona
# 8670                                   WND Books  2016      Washington, DC
# 8671                               WorldNetDaily  2016      Washington, DC
# 8673  Little Shell Pembina Band of North America  2010  Pembina River Area
# 8688  Little Shell Pembina Band of North America  2010  Pembina River Area
#
#       ST Militia Militia2             state_city             ...               \
# 0     CO      No       No           CO_Johnstown             ...
# 1     CA      No       No         CA_Lemon Grove             ...
# 2     WI      No       No            WI_Appleton             ...
# 3     WI      No       No            WI_Appleton             ...
# 4     WI      No       No            WI_Appleton             ...
# 5     AZ      No       No            AZ_Glendale             ...
# 6     AZ      No      Yes             AZ_Douglas             ...
# 7     AZ      No      Yes            AZ_Glendale             ...
# 9     MN      No       No         MN_Cedar Falls             ...
# 10    TX      No       No          TX_Richardson             ...
# 11    TX      No       No            TX_Cleburne             ...
# 12    CA      No      Yes                CA_Brea             ...
# 13    NV      No       No        NV_Sandy Valley             ...
# 14    TX      No       No          TX_Waxahachie             ...
# 15    CO      No       No          CO_Canon City             ...
# 16    CT      No       No         CT_Middlefield             ...
# 17    AK      No       No               AK_Kenai             ...
# 18    AL      No       No             AL_Cullman             ...
# 19    AR      No       No        AR_Fayetteville             ...
# 20    AZ      No       No       AZ_Golden Valley             ...
# 21    CO      No       No              CO_Arvada             ...
# 22    CT      No       No             CT_Wolcott             ...
# 23    DC      No       No          DC_Washington             ...
# 24    DE      No       No          DE_Middletown             ...
# 25    FL      No       No             FL_Jupiter             ...
# 26    GA      No       No           GA_Woodstock             ...
# 27    HI      No       No            HI_Honolulu             ...
# 28    IA      No       No           IA_Oskaloosa             ...
# 29    ID      No       No               ID_Parma             ...
# 30    IL      No       No     IL_Rolling Meadows             ...
# ...   ..     ...      ...                    ...             ...
# 8642  WA     Yes      Yes      WA_Spokane County             ...
# 8643  WA     Yes      Yes       WA_Yakima County             ...
# 8644  CA      No       No           CA_San Pedro             ...
# 8645  KY      No       No           KY_Lexington             ...
# 8647  ME     Yes      Yes             ME_Sanford             ...
# 8648  CA      No       No              CA_Fresno             ...
# 8649  CA      No       No         CA_Los Angeles             ...
# 8650  CA      No       No         CA_Los Angeles             ...
# 8652  CO      No       No          CO_Walsenburg             ...
# 8653  CT      No       No           CT_Waterbury             ...
# 8654  FL      No       No             FL_Orlando             ...
# 8655  FL      No       No          FL_Palm Beach             ...
# 8656  FL      No       No               FL_Tampa             ...
# 8657  IL      No       No             IL_Chicago             ...
# 8658  ME      No       No              ME_Bangor             ...
# 8659  MI      No       No        MI_Grand Rapids             ...
# 8660  NH      No       No          NH_Manchester             ...
# 8661  NV      No       No           NV_Las Vegas             ...
# 8662  RI      No       No          RI_Providence             ...
# 8663  WA      No       No             WA_Spokane             ...
# 8664  NY      No       No          NY_Queensbury             ...
# 8665  MI     Yes      Yes     MI_Muskegon County             ...
# 8666  OR     Yes      Yes      OR_Yamhill County             ...
# 8667  PA      No       No          PA_Grove City             ...
# 8668  NH      No       No             NH_Concord             ...
# 8669  FL      No       No       FL_South Daytona             ...
# 8670  DC      No       No      DC_Washington, DC             ...
# 8671  DC      No       No      DC_Washington, DC             ...
# 8673  ND      No       No  ND_Pembina River Area             ...
# 8688  ND      No       No  ND_Pembina River Area             ...
#
#        P3_merge  flag_p12            County_P3                County_P4 Final  \
# 0          both     Match          Weld County              Weld County   NaN
# 1          both     Match     San Diego County         San Diego County   NaN
# 2          both     Match     Outagamie County         Outagamie County   NaN
# 3          both  Mismatch                Error           Calumet County   NaN
# 4          both  Mismatch                Error         Winnebago County   NaN
# 5          both     Match      Maricopa County          Maricopa County   NaN
# 6     left_only  Mismatch       Cochise County           Cochise County   NaN
# 7          both     Match      Maricopa County          Maricopa County   NaN
# 9     left_only  No Match             No Match                 No Match   NaN
# 10         both     Match        Dallas County            Dallas County   NaN
# 11         both     Match       Johnson County           Johnson County   NaN
# 12         both     Match        Orange County            Orange County   NaN
# 13    left_only  No Match             No Match                 No Match   1.0
# 14         both     Match         Ellis County             Ellis County   NaN
# 15    left_only  Mismatch       Fremont County           Fremont County   NaN
# 16    left_only  Mismatch     Middlesex County         Middlesex County   NaN
# 17         both  Mismatch                Error  Kenai Peninsula Borough   NaN
# 18         both     Match       Cullman County           Cullman County   NaN
# 19         both     Match    Washington County        Washington County   NaN
# 20    left_only  Mismatch        Mohave County            Mohave County   NaN
# 21         both     Match     Jefferson County         Jefferson County   NaN
# 22    left_only  Mismatch     New Haven County         New Haven County   NaN
# 23         both  Mismatch                Error     District of Columbia   NaN
# 24         both     Match    New Castle County        New Castle County   NaN
# 25         both     Match    Palm Beach County        Palm Beach County   NaN
# 26         both     Match      Cherokee County          Cherokee County   NaN
# 27    left_only  Mismatch      Honolulu County          Honolulu County   NaN
# 28         both     Match       Mahaska County           Mahaska County   NaN
# 29    left_only  Mismatch        Canyon County            Canyon County   NaN
# 30         both     Match          Cook County              Cook County   NaN
# ...         ...       ...                  ...                      ...   ...
# 8642       both     Match       Spokane County           Spokane County   NaN
# 8643       both     Match        Yakima County            Yakima County   NaN
# 8644  left_only  Mismatch   Los Angeles County       Los Angeles County   NaN
# 8645       both     Match       Fayette County           Fayette County   NaN
# 8647  left_only  Mismatch          York County              York County   NaN
# 8648       both     Match        Fresno County            Fresno County   NaN
# 8649       both     Match   Los Angeles County       Los Angeles County   NaN
# 8650       both     Match   Los Angeles County       Los Angeles County   NaN
# 8652  left_only  Mismatch      Huerfano County          Huerfano County   NaN
# 8653       both     Match     New Haven County         New Haven County   NaN
# 8654       both  Mismatch                Error            Orange County   NaN
# 8655       both     Match    Palm Beach County        Palm Beach County   NaN
# 8656       both     Match  Hillsborough County      Hillsborough County   NaN
# 8657       both     Match          Cook County              Cook County   NaN
# 8658       both     Match     Penobscot County         Penobscot County   NaN
# 8659       both     Match          Kent County              Kent County   NaN
# 8660       both     Match  Hillsborough County      Hillsborough County   NaN
# 8661       both     Match         Clark County             Clark County   NaN
# 8662       both     Match    Providence County        Providence County   NaN
# 8663       both     Match       Spokane County           Spokane County   NaN
# 8664  left_only  Mismatch        Warren County            Warren County   NaN
# 8665       both     Match      Muskegon County          Muskegon County   NaN
# 8666       both     Match       Yamhill County           Yamhill County   NaN
# 8667  left_only  Mismatch        Mercer County            Mercer County   NaN
# 8668       both     Match     Merrimack County         Merrimack County   NaN
# 8669       both  Mismatch       Volusia County           Volusia County   1.0
# 8670  left_only  No Match             No Match                 No Match   1.0
# 8671  left_only  No Match             No Match                 No Match   1.0
# 8673  left_only  No Match             No Match                 No Match   NaN
# 8688  left_only  No Match             No Match                 No Match   NaN
#
#                              Fix2 Note testcheck_merge  \
# 0                             NaN  NaN       left_only
# 1                             NaN  NaN       left_only
# 2                             NaN  NaN       left_only
# 3                             NaN  NaN       left_only
# 4                             NaN  NaN       left_only
# 5                             NaN  NaN       left_only
# 6                             NaN  NaN       left_only
# 7                             NaN  NaN       left_only
# 9                             NaN  NaN       left_only
# 10                            NaN  NaN       left_only
# 11                            NaN  NaN       left_only
# 12                            NaN  NaN       left_only
# 13                   Clark County  NaN            both
# 14                            NaN  NaN       left_only
# 15                            NaN  NaN       left_only
# 16                            NaN  NaN       left_only
# 17                            NaN  NaN       left_only
# 18                            NaN  NaN       left_only
# 19                            NaN  NaN       left_only
# 20                            NaN  NaN       left_only
# 21                            NaN  NaN       left_only
# 22                            NaN  NaN       left_only
# 23                            NaN  NaN       left_only
# 24                            NaN  NaN       left_only
# 25                            NaN  NaN       left_only
# 26                            NaN  NaN       left_only
# 27                            NaN  NaN       left_only
# 28                            NaN  NaN       left_only
# 29                            NaN  NaN       left_only
# 30                            NaN  NaN       left_only
# ...                           ...  ...             ...
# 8642                          NaN  NaN       left_only
# 8643                          NaN  NaN       left_only
# 8644                          NaN  NaN       left_only
# 8645                          NaN  NaN       left_only
# 8647                          NaN  NaN       left_only
# 8648                          NaN  NaN       left_only
# 8649                          NaN  NaN       left_only
# 8650                          NaN  NaN       left_only
# 8652                          NaN  NaN       left_only
# 8653                          NaN  NaN       left_only
# 8654                          NaN  NaN       left_only
# 8655                          NaN  NaN       left_only
# 8656                          NaN  NaN       left_only
# 8657                          NaN  NaN       left_only
# 8658                          NaN  NaN       left_only
# 8659                          NaN  NaN       left_only
# 8660                          NaN  NaN       left_only
# 8661                          NaN  NaN       left_only
# 8662                          NaN  NaN       left_only
# 8663                          NaN  NaN       left_only
# 8664                          NaN  NaN       left_only
# 8665                          NaN  NaN       left_only
# 8666                          NaN  NaN       left_only
# 8667                          NaN  NaN       left_only
# 8668                          NaN  NaN       left_only
# 8669               Volusia County  NaN            both
# 8670  District of Columbia County  NaN            both
# 8671  District of Columbia County  NaN            both
# 8673                          NaN  NaN       left_only
# 8688                          NaN  NaN       left_only
#
#                         County_P5                    County_P6
# 0                     Weld County                  Weld County
# 1                San Diego County             San Diego County
# 2                Outagamie County             Outagamie County
# 3                  Calumet County               Calumet County
# 4                Winnebago County             Winnebago County
# 5                 Maricopa County              Maricopa County
# 6                  Cochise County               Cochise County
# 7                 Maricopa County              Maricopa County
# 9                        No Match            Black Hawk County
# 10                  Dallas County                Dallas County
# 11                 Johnson County               Johnson County
# 12                  Orange County                Orange County
# 13                   Clark County                 Clark County
# 14                   Ellis County                 Ellis County
# 15                 Fremont County               Fremont County
# 16               Middlesex County             Middlesex County
# 17        Kenai Peninsula Borough      Kenai Peninsula Borough
# 18                 Cullman County               Cullman County
# 19              Washington County            Washington County
# 20                  Mohave County                Mohave County
# 21               Jefferson County             Jefferson County
# 22               New Haven County             New Haven County
# 23           District of Columbia         District of Columbia
# 24              New Castle County            New Castle County
# 25              Palm Beach County            Palm Beach County
# 26                Cherokee County              Cherokee County
# 27                Honolulu County              Honolulu County
# 28                 Mahaska County               Mahaska County
# 29                  Canyon County                Canyon County
# 30                    Cook County                  Cook County
# ...                           ...                          ...
# 8642               Spokane County               Spokane County
# 8643                Yakima County                Yakima County
# 8644           Los Angeles County           Los Angeles County
# 8645               Fayette County               Fayette County
# 8647                  York County                  York County
# 8648                Fresno County                Fresno County
# 8649           Los Angeles County           Los Angeles County
# 8650           Los Angeles County           Los Angeles County
# 8652              Huerfano County              Huerfano County
# 8653             New Haven County             New Haven County
# 8654                Orange County                Orange County
# 8655            Palm Beach County            Palm Beach County
# 8656          Hillsborough County          Hillsborough County
# 8657                  Cook County                  Cook County
# 8658             Penobscot County             Penobscot County
# 8659                  Kent County                  Kent County
# 8660          Hillsborough County          Hillsborough County
# 8661                 Clark County                 Clark County
# 8662            Providence County            Providence County
# 8663               Spokane County               Spokane County
# 8664                Warren County                Warren County
# 8665              Muskegon County              Muskegon County
# 8666               Yamhill County               Yamhill County
# 8667                Mercer County                Mercer County
# 8668             Merrimack County             Merrimack County
# 8669               Volusia County               Volusia County
# 8670  District of Columbia County  District of Columbia County
# 8671  District of Columbia County  District of Columbia County
# 8673                     No Match               Pembina County
# 8688                     No Match              Cavalier County
#
# [6767 rows x 25 columns]

# %%
# NOW ASSIGN FIPS codes

# Import dataset with County to FIPS code conversion
county_FIPS = pd.read_csv("national_county.txt", header = None, names = ["ST", "ID1", "ID2", "County", "ID3"], dtype = object)
county_FIPS["state_county"] = county_FIPS["ST"] + "_" + county_FIPS["County"]
county_FIPS['fips'] = county_FIPS.ID1.map(str) + county_FIPS.ID2.map(str)
county_FIPS.head()

# Create dictionary of County to FIPS code
tryit2_dict = dict(zip(county_FIPS.state_county, county_FIPS.fips))

# Create state county field
check2['state_county'] = check2.ST + "_" + check2.County_P6

# Map state_county to to SPLC dataset using tryit2_dict, with state_county as key
check2["fips1"] = check2["state_county"].map(tryit2_dict)

# Export to Excel for final check for those records that should be dropped (ex. locations listed as Statewide or Unknown 
# or are unable to be matched.)
check2.to_excel("SPLC_CheckIt_Thrice.xlsx")

# %%
# Import results from final check
df = pd.read_excel('SPLC_CheckIt_Thrice_Done.xlsx')

# Drop records that were verified for removal
check3 = df[df['Check'] != 'dropit'].copy()

# Assign final county based on results from the final check
check3['County_P7'] = np.where((~pd.isnull(check3.Add)), check3.Add, check3.County_P6)

# Create state county field
check3['state_county3'] = check3.ST + "_" + check3.County_P7

# Map fips to newly assigned county records using tryit2_dict, with state_county as key
check3["fips2"] = check3["state_county3"].map(tryit2_dict)

#check3[(pd.isnull(check3.fips2)) & ((check3.County_P7 != 'None') & (check3.County_P7 !='No Match'))]

# Filter those records that have a fips assigned (no fips means it is a deliberate no match)
done = check3[~pd.isnull(check3.fips2)][['State', 'Name', 'Year', 'Raw', 'ST',\
                                         'Militia', 'Militia2', 'County_P7', 'fips2' ]]

# Export results to Excel for final analysis
done.to_excel('SPLC_CLEAN.xlsx')
# Out:
#       Column3  Column2  Column1           State  \
# 0        5961     5961     5806          Alaska
# 1        7976     7976     7852          Alaska
# 2        8030     8030     7853          Alaska
# 3        8049     8049     7854          Alaska
# 4        8066     8066     7855          Alaska
# 5        8112     8112     7856          Alaska
# 6        8183     8183     7850          Alaska
# 7        8341     8341     7857          Alaska
# 8        8535     8535     7858          Alaska
# 9        8583     8583     7859          Alaska
# 10       7962     7962     7836         Alabama
# 11       7977     7977     7837         Alabama
# 12       8065     8065     7839         Alabama
# 13       8064     8064     7838         Alabama
# 14       8113     8113     7840         Alabama
# 15       8146     8146     7842         Alabama
# 16       8153     8153     7841         Alabama
# 17       8168     8168     7834         Alabama
# 18       8184     8184     7835         Alabama
# 19       8250     8250     7843         Alabama
# 20       8304     8304     7844         Alabama
# 21       8310     8310     7845         Alabama
# 22       8342     8342     7846         Alabama
# 23       8523     8523     7847         Alabama
# 24       8533     8533     7848         Alabama
# 25       8584     8584     7849         Alabama
# 26       7978     7978     7885        Arkansas
# 27       8038     8038     7886        Arkansas
# 28       8067     8067     7887        Arkansas
# 29       8114     8114     7888        Arkansas
# ...       ...      ...      ...             ...
# 8660       58       58      115  South Carolina
# 8661      129      129      116  South Carolina
# 8662       59       59      117    South Dakota
# 8663       60       60      118    South Dakota
# 8664       61       61      119       Tennessee
# 8665      102      102      120       Tennessee
# 8666       10       10      121           Texas
# 8667       11       11      122           Texas
# 8668       14       14      123           Texas
# 8669       62       62      124           Texas
# 8670       72       72      125           Texas
# 8671      131      131      126           Texas
# 8672       63       63      127            Utah
# 8673       64       64      129        Virginia
# 8674     1012     1012     1733       Wisconsin
# 8675       65       65      128         Vermont
# 8676       66       66      131      Washington
# 8677      103      103      132      Washington
# 8678        2        2      135       Wisconsin
# 8679        3        3      136       Wisconsin
# 8680        4        4      137       Wisconsin
# 8681       67       67      138       Wisconsin
# 8682       68       68      139       Wisconsin
# 8683       69       69      140       Wisconsin
# 8684      104      104      141       Wisconsin
# 8685      105      105      142       Wisconsin
# 8686      106      106      143       Wisconsin
# 8687       70       70      133   West Virginia
# 8688     1660       85      134   West Virginia
# 8689       71       71      144         Wyoming
#
#                                                    Name  Year             Raw  \
# 0                              Bethel Citizens Militia*  2014        Tuluksak
# 1                                American Patriots III%  2016       Statewide
# 2                 Anchorage Municipality Defense Force*  2016       Anchorage
# 3                               Central Alaska Militia*  2016  Delta Junction
# 4                          Constitution Party of Alaska  2016        Soldotna
# 5                                           Eagle Forum  2016         Cordova
# 6                                 III% United Patriots*  2016       Statewide
# 7                                          Oath Keepers  2016       Anchorage
# 8                               South Central Patriots*  2016         Wasilla
# 9                         Three Percenters-III%ers, The  2016       Statewide
# 10                      Alabama Constitutional Militia*  2016         Clanton
# 11                               American Patriots III%  2016       Statewide
# 12                        Constitution Party of Alabama  2016      Montgomery
# 13                        Constitution Party of Alabama  2016      Adamsville
# 14                                          Eagle Forum  2016      Birmingham
# 15                                   Free Patriot Press  2016      Birmingham
# 16                                         Freedom Yell  2016           Ozark
# 17                                 III% Security Force*  2016       Statewide
# 18                                III% United Patriots*  2016       Statewide
# 19                                   John Birch Society  2016          Mobile
# 20                                      LewRockwell.com  2016          Auburn
# 21                  Limestone County Constitution Party  2016          Athens
# 22                                         Oath Keepers  2016     Bay Minette
# 23            Republic for the united States of America  2016          Dothan
# 24                               South Alabama Militia*  2016          Dothan
# 25                        Three Percenters-III%ers, The  2016   Shelby County
# 26                               American Patriots III%  2016       Statewide
# 27                        Arkansas State Militia Corps*  2016       Mansfield
# 28                       Constitution Party of Arkansas  2016    Fayetteville
# 29                                          Eagle Forum  2016     Little Rock
# ...                                                 ...   ...             ...
# 8660                                 Constitution Party  2007      Greenville
# 8661                                    Patriot Network  2007        Anderson
# 8662                                 Constitution Party  2007     Sioux Falls
# 8663                                 Constitution Party  2007     Sioux Falls
# 8664                                 Constitution Party  2007      Germantown
# 8665                                 John Birch Society  2007  Hendersonville
# 8666                                      Border Rescue  2007      Richardson
# 8667                                Buffalo Creek Press  2007        Cleburne
# 8668             Church of God Evangelistic Association  2007      Waxahachie
# 8669                                 Constitution Party  2007       Kerrville
# 8670                               Constitution Society  2007          Austin
# 8671                                  Republic of Texas  2007         Overton
# 8672                                 Constitution Party  2007          Layton
# 8673                                 Constitution Party  2007          Vienna
# 8674                     Confederate States Home Guard*  2010        Somerset
# 8675                                 Constitution Party  2007       Williston
# 8676                                 Constitution Party  2007          Tacoma
# 8677                                 John Birch Society  2007       Clarkston
# 8678                     American Opinion Book Services  2007        Appleton
# 8679                     American Opinion Book Services  2007        Appleton
# 8680                     American Opinion Book Services  2007        Appleton
# 8681                                 Constitution Party  2007        Appleton
# 8682                                 Constitution Party  2007        Appleton
# 8683                                 Constitution Party  2007        Appleton
# 8684                                 John Birch Society  2007        Appleton
# 8685                                 John Birch Society  2007        Appleton
# 8686                                 John Birch Society  2007        Appleton
# 8687                                 Constitution Party  2007     Martinsburg
# 8688  Guerilla Operations and Tactics Squad - G.O.A....  2007   Hampton Roads
# 8689                                 Constitution Party  2007   Mountain View
#
#       ST Militia Militia2  ...                          County_P5  \
# 0     AK     Yes      Yes  ...                      Bethel County
# 1     AK      No       No  ...                               None
# 2     AK     Yes      Yes  ...             Anchorage Municipality
# 3     AK     Yes      Yes  ...    Southeast Fairbanks Census Area
# 4     AK      No       No  ...            Kenai Peninsula Borough
# 5     AK      No       No  ...         Valdez-Cordova Census Area
# 6     AK     Yes      Yes  ...                               None
# 7     AK      No       No  ...             Anchorage Municipality
# 8     AK     Yes      Yes  ...          Matanuska-Susitna Borough
# 9     AK      No       No  ...                               None
# 10    AL     Yes      Yes  ...                     Chilton County
# 11    AL      No       No  ...                               None
# 12    AL      No       No  ...                  Montgomery County
# 13    AL      No       No  ...                   Jefferson County
# 14    AL      No       No  ...                   Jefferson County
# 15    AL      No       No  ...                   Jefferson County
# 16    AL      No       No  ...                        Dale County
# 17    AL     Yes      Yes  ...                               None
# 18    AL     Yes      Yes  ...                               None
# 19    AL      No       No  ...                      Mobile County
# 20    AL      No       No  ...                         Lee County
# 21    AL      No       No  ...                   Limestone County
# 22    AL      No       No  ...                     Baldwin County
# 23    AL      No       No  ...                     Houston County
# 24    AL     Yes      Yes  ...                     Houston County
# 25    AL      No       No  ...                      Shelby County
# 26    AR      No       No  ...                               None
# 27    AR     Yes      Yes  ...                       Scott County
# 28    AR      No       No  ...                  Washington County
# 29    AR      No       No  ...                     Pulaski County
# ...   ..     ...      ...  ...                                ...
# 8660  SC      No       No  ...                  Greenville County
# 8661  SC      No       No  ...                    Anderson County
# 8662  SD      No       No  ...                   Minnehaha County
# 8663  SD      No       No  ...                     Lincoln County
# 8664  TN      No       No  ...                      Shelby County
# 8665  TN      No       No  ...                      Sumner County
# 8666  TX      No       No  ...                      Dallas County
# 8667  TX      No       No  ...                     Johnson County
# 8668  TX      No       No  ...                       Ellis County
# 8669  TX      No       No  ...                        Kerr County
# 8670  TX      No       No  ...                      Travis County
# 8671  TX      No       No  ...                        Rusk County
# 8672  UT      No       No  ...                       Davis County
# 8673  VA      No       No  ...                     Fairfax County
# 8674  WI     Yes      Yes  ...                 Saint Croix County
# 8675  VT      No       No  ...                  Chittenden County
# 8676  WA      No       No  ...                      Pierce County
# 8677  WA      No       No  ...                      Asotin County
# 8678  WI      No       No  ...                   Outagamie County
# 8679  WI      No       No  ...                     Calumet County
# 8680  WI      No       No  ...                   Winnebago County
# 8681  WI      No       No  ...                   Outagamie County
# 8682  WI      No       No  ...                     Calumet County
# 8683  WI      No       No  ...                   Winnebago County
# 8684  WI      No       No  ...                   Outagamie County
# 8685  WI      No       No  ...                     Calumet County
# 8686  WI      No       No  ...                   Winnebago County
# 8687  WV      No       No  ...                    Berkeley County
# 8688  WV      No       No  ...                           No Match
# 8689  WY      No       No  ...                       Uinta County
#
#                             County_P6                        state_county  \
# 0                       Bethel County                    AK_Bethel County
# 1                                None                             AK_None
# 2              Anchorage Municipality           AK_Anchorage Municipality
# 3     Southeast Fairbanks Census Area  AK_Southeast Fairbanks Census Area
# 4             Kenai Peninsula Borough          AK_Kenai Peninsula Borough
# 5          Valdez-Cordova Census Area       AK_Valdez-Cordova Census Area
# 6                                None                             AK_None
# 7              Anchorage Municipality           AK_Anchorage Municipality
# 8           Matanuska-Susitna Borough        AK_Matanuska-Susitna Borough
# 9                                None                             AK_None
# 10                     Chilton County                   AL_Chilton County
# 11                               None                             AL_None
# 12                  Montgomery County                AL_Montgomery County
# 13                   Jefferson County                 AL_Jefferson County
# 14                   Jefferson County                 AL_Jefferson County
# 15                   Jefferson County                 AL_Jefferson County
# 16                        Dale County                      AL_Dale County
# 17                               None                             AL_None
# 18                               None                             AL_None
# 19                      Mobile County                    AL_Mobile County
# 20                         Lee County                       AL_Lee County
# 21                   Limestone County                 AL_Limestone County
# 22                     Baldwin County                   AL_Baldwin County
# 23                     Houston County                   AL_Houston County
# 24                     Houston County                   AL_Houston County
# 25                      Shelby County                    AL_Shelby County
# 26                               None                             AR_None
# 27                       Scott County                     AR_Scott County
# 28                  Washington County                AR_Washington County
# 29                     Pulaski County                   AR_Pulaski County
# ...                               ...                                 ...
# 8660                Greenville County                SC_Greenville County
# 8661                  Anderson County                  SC_Anderson County
# 8662                 Minnehaha County                 SD_Minnehaha County
# 8663                   Lincoln County                   SD_Lincoln County
# 8664                    Shelby County                    TN_Shelby County
# 8665                    Sumner County                    TN_Sumner County
# 8666                    Dallas County                    TX_Dallas County
# 8667                   Johnson County                   TX_Johnson County
# 8668                     Ellis County                     TX_Ellis County
# 8669                      Kerr County                      TX_Kerr County
# 8670                    Travis County                    TX_Travis County
# 8671                      Rusk County                      TX_Rusk County
# 8672                     Davis County                     UT_Davis County
# 8673                   Fairfax County                   VA_Fairfax County
# 8674               Saint Croix County               WI_Saint Croix County
# 8675                Chittenden County                VT_Chittenden County
# 8676                    Pierce County                    WA_Pierce County
# 8677                    Asotin County                    WA_Asotin County
# 8678                 Outagamie County                 WI_Outagamie County
# 8679                   Calumet County                   WI_Calumet County
# 8680                 Winnebago County                 WI_Winnebago County
# 8681                 Outagamie County                 WI_Outagamie County
# 8682                   Calumet County                   WI_Calumet County
# 8683                 Winnebago County                 WI_Winnebago County
# 8684                 Outagamie County                 WI_Outagamie County
# 8685                   Calumet County                   WI_Calumet County
# 8686                 Winnebago County                 WI_Winnebago County
# 8687                  Berkeley County                  WV_Berkeley County
# 8688                         No Match                         WV_No Match
# 8689                     Uinta County                     WY_Uinta County
#
#         fips1 fips_id   Check                 Add  \
# 0         NaN     NaN   Keep2  Bethel Census Area
# 1         NaN     NaN  st_unk                 NaN
# 2      2020.0    20.0   Keep2                 NaN
# 3      2240.0   240.0   Keep2                 NaN
# 4      2122.0   122.0   Keep2                 NaN
# 5      2261.0   261.0   Keep2                 NaN
# 6         NaN     NaN  st_unk                 NaN
# 7      2020.0    20.0   Keep2                 NaN
# 8      2170.0   170.0   Keep2                 NaN
# 9         NaN     NaN  st_unk                 NaN
# 10     1021.0    21.0     NaN                 NaN
# 11        NaN     NaN  st_unk                 NaN
# 12     1101.0   101.0     NaN                 NaN
# 13     1073.0     NaN     NaN                 NaN
# 14     1073.0    73.0     NaN                 NaN
# 15     1073.0    73.0     NaN                 NaN
# 16     1045.0    45.0     NaN                 NaN
# 17        NaN     NaN  st_unk                 NaN
# 18        NaN     NaN  st_unk                 NaN
# 19     1097.0    97.0     NaN                 NaN
# 20     1081.0    81.0     NaN                 NaN
# 21     1083.0    83.0     NaN                 NaN
# 22     1003.0     3.0     NaN                 NaN
# 23     1069.0    69.0     NaN                 NaN
# 24     1069.0    69.0     NaN                 NaN
# 25     1117.0     NaN     NaN                 NaN
# 26        NaN     NaN  st_unk                 NaN
# 27     5127.0     NaN     NaN                 NaN
# 28     5143.0   143.0     NaN                 NaN
# 29     5119.0   119.0     NaN                 NaN
# ...       ...     ...     ...                 ...
# 8660  45045.0    45.0   Keep2                 NaN
# 8661  45007.0     7.0     NaN                 NaN
# 8662  46099.0    99.0     NaN                 NaN
# 8663  46083.0    83.0   Keep2                 NaN
# 8664  47157.0   157.0     NaN                 NaN
# 8665  47165.0   165.0     NaN                 NaN
# 8666  48113.0   113.0     NaN                 NaN
# 8667  48251.0   251.0     NaN                 NaN
# 8668  48139.0   139.0     NaN                 NaN
# 8669  48265.0   265.0     NaN                 NaN
# 8670  48453.0   453.0     NaN                 NaN
# 8671  48401.0   401.0     NaN                 NaN
# 8672  49011.0    11.0     NaN                 NaN
# 8673  51059.0    59.0     NaN                 NaN
# 8674      NaN     NaN   Keep2    St. Croix County
# 8675  50007.0     NaN     NaN                 NaN
# 8676  53053.0    53.0     NaN                 NaN
# 8677  53003.0     NaN     NaN                 NaN
# 8678  55087.0    87.0   Keep2                 NaN
# 8679  55015.0    15.0   Keep2                 NaN
# 8680  55139.0   139.0   Keep2                 NaN
# 8681  55087.0    87.0     NaN                 NaN
# 8682  55015.0    15.0   Keep2                 NaN
# 8683  55139.0   139.0   Keep2                 NaN
# 8684  55087.0    87.0     NaN                 NaN
# 8685  55015.0    15.0   Keep2                 NaN
# 8686  55139.0   139.0   Keep2                 NaN
# 8687  54003.0     NaN     NaN                 NaN
# 8688      NaN     NaN       0                 NaN
# 8689  56041.0     NaN     NaN                 NaN
#
#                             County_P7                       state_county3  \
# 0                  Bethel Census Area               AK_Bethel Census Area
# 1                                None                             AK_None
# 2              Anchorage Municipality           AK_Anchorage Municipality
# 3     Southeast Fairbanks Census Area  AK_Southeast Fairbanks Census Area
# 4             Kenai Peninsula Borough          AK_Kenai Peninsula Borough
# 5          Valdez-Cordova Census Area       AK_Valdez-Cordova Census Area
# 6                                None                             AK_None
# 7              Anchorage Municipality           AK_Anchorage Municipality
# 8           Matanuska-Susitna Borough        AK_Matanuska-Susitna Borough
# 9                                None                             AK_None
# 10                     Chilton County                   AL_Chilton County
# 11                               None                             AL_None
# 12                  Montgomery County                AL_Montgomery County
# 13                   Jefferson County                 AL_Jefferson County
# 14                   Jefferson County                 AL_Jefferson County
# 15                   Jefferson County                 AL_Jefferson County
# 16                        Dale County                      AL_Dale County
# 17                               None                             AL_None
# 18                               None                             AL_None
# 19                      Mobile County                    AL_Mobile County
# 20                         Lee County                       AL_Lee County
# 21                   Limestone County                 AL_Limestone County
# 22                     Baldwin County                   AL_Baldwin County
# 23                     Houston County                   AL_Houston County
# 24                     Houston County                   AL_Houston County
# 25                      Shelby County                    AL_Shelby County
# 26                               None                             AR_None
# 27                       Scott County                     AR_Scott County
# 28                  Washington County                AR_Washington County
# 29                     Pulaski County                   AR_Pulaski County
# ...                               ...                                 ...
# 8660                Greenville County                SC_Greenville County
# 8661                  Anderson County                  SC_Anderson County
# 8662                 Minnehaha County                 SD_Minnehaha County
# 8663                   Lincoln County                   SD_Lincoln County
# 8664                    Shelby County                    TN_Shelby County
# 8665                    Sumner County                    TN_Sumner County
# 8666                    Dallas County                    TX_Dallas County
# 8667                   Johnson County                   TX_Johnson County
# 8668                     Ellis County                     TX_Ellis County
# 8669                      Kerr County                      TX_Kerr County
# 8670                    Travis County                    TX_Travis County
# 8671                      Rusk County                      TX_Rusk County
# 8672                     Davis County                     UT_Davis County
# 8673                   Fairfax County                   VA_Fairfax County
# 8674                 St. Croix County                 WI_St. Croix County
# 8675                Chittenden County                VT_Chittenden County
# 8676                    Pierce County                    WA_Pierce County
# 8677                    Asotin County                    WA_Asotin County
# 8678                 Outagamie County                 WI_Outagamie County
# 8679                   Calumet County                   WI_Calumet County
# 8680                 Winnebago County                 WI_Winnebago County
# 8681                 Outagamie County                 WI_Outagamie County
# 8682                   Calumet County                   WI_Calumet County
# 8683                 Winnebago County                 WI_Winnebago County
# 8684                 Outagamie County                 WI_Outagamie County
# 8685                   Calumet County                   WI_Calumet County
# 8686                 Winnebago County                 WI_Winnebago County
# 8687                  Berkeley County                  WV_Berkeley County
# 8688                         No Match                         WV_No Match
# 8689                     Uinta County                     WY_Uinta County
#
#       fips2
# 0     02050
# 1       NaN
# 2     02020
# 3     02240
# 4     02122
# 5     02261
# 6       NaN
# 7     02020
# 8     02170
# 9       NaN
# 10    01021
# 11      NaN
# 12    01101
# 13    01073
# 14    01073
# 15    01073
# 16    01045
# 17      NaN
# 18      NaN
# 19    01097
# 20    01081
# 21    01083
# 22    01003
# 23    01069
# 24    01069
# 25    01117
# 26      NaN
# 27    05127
# 28    05143
# 29    05119
# ...     ...
# 8660  45045
# 8661  45007
# 8662  46099
# 8663  46083
# 8664  47157
# 8665  47165
# 8666  48113
# 8667  48251
# 8668  48139
# 8669  48265
# 8670  48453
# 8671  48401
# 8672  49011
# 8673  51059
# 8674  55109
# 8675  50007
# 8676  53053
# 8677  53003
# 8678  55087
# 8679  55015
# 8680  55139
# 8681  55087
# 8682  55015
# 8683  55139
# 8684  55087
# 8685  55015
# 8686  55139
# 8687  54003
# 8688    NaN
# 8689  56041
#
# [8678 rows x 32 columns]
